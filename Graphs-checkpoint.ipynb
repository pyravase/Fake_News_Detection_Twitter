# %%
from collections import Counter
import nltk
import pandas as pd
import numpy as np
import plotly
from plotly import graph_objs

# %%
tweetsData = pd.read_csv("FinalDataSet.csv" , encoding = "ISO-8859-1")

# %%
tweetsData.shape
# Out:
# (250, 22)

# %%
tweetsData.head(50)
# Out:
#     Unique ID                                               text  \
# 0           1  Hurricane Katrina - Saints go to the Superbowl...
# 1           2  Students from Riverview Elementary set a goal ...
# 2           3  Harvey caused more than $74M in damage to floo...
# 3           4  I added a video to a @YouTube playlist https:/...
# 4           5  DFW businesses accused of price gouging during...
# 5           6  Stories of homeowners hoping 4 a buyout after ...
# 6           7  9 Weeks After Harvey, Houston Celebrates World...
# 7           8  @BestFriends recounts their work in animal sea...
# 8           9  Companies like @Walmart have made an effort to...
# 9          10  The Energy Industry Is Stepping Up In The Wake...
# 10         11  Hurricane Harvey washes up a mysterious creatu...
# 11         12  @sethmeyers plz help mr.meyers my family is sh...
# 12         13  How Otis Became A Symbol of Strength During Hu...
# 13         14  Jobs report-261,000 despite hurricane Harvey &...
# 14         15   @CharityNav We're sending our guys who were a...
# 15         16  12 nonprofits received funding to help meet th...
# 16         17  Hurricane Harvey/Brazos River Flood Recovery R...
# 17         18  Bonfire Wings was recently recognized for dona...
# 18         19  Hurricane Harvey Drove Houstonâs Undocumente...
# 19         20  super bowl 51, 51 inches of rain fell during h...
# 20         21  Congrats Houston! 9 Weeks After Harvey, Housto...
# 21         22  Hurricane Harvey washes up a mysterious creatu...
# 22         23  GalvCoTX: Following the unprecedented flooding...
# 23         24  "Faith in the Water" on iTunes now!  All profi...
# 24         25  The Energy Industry Is Stepping Up In The Wake...
# 25         26  Our ð¬DWEâ¤ï¸feel the love! @ProjectLinus ...
# 26         27  Hurricane Harvey washes up a mysterious creatu...
# 27         28  RAAF, @Crayola, and Good360 have come together...
# 28         29  Tracey and her daughter are victims of #hurric...
# 29         30  Houston Astros Win 2017 World Series Help Regi...
# 30         31  Hurricane Harvey hero "Mattress Mack" out $10 ...
# 31         32  DFW businesses accused of price gouging during...
# 32         33  Toys for Tots organizers double efforts after ...
# 33         34  DFW businesses accused of price gouging during...
# 34         35  Harvey caused more than $74M in damage to floo...
# 35         36  TXSG has an ongoing role in Hurricane Harvey r...
# 36         37  Thank you fans! @MiLB teams and MILB Charities...
# 37         38  After Hurricane Harvey, Houston takes a fall t...
# 38         39  Toys for Tots organizers double efforts after ...
# 39         40  Tommy is one of the pups that were rescued dur...
# 40         41  Hurricane Harvey hero 'Mattress Mack' out $10 ...
# 41         42  These #UTSA students are collecting water samp...
# 42         43  BIF: Just Two Months After Hurricane Harvey, H...
# 43         44  WSU student uses drone to help people after Hu...
# 44         45  Drone Software Donation for Hurricane Recovery...
# 45         46  WSU student uses drone to help people after Hu...
# 46         47  Hewlett Packard moving jobs to Chippewa Falls ...
# 47         48  Much of Houston has moved on since Hurricane H...
# 48         49  9/11- The Patriots won the Super Bowl. Hurrica...
# 49         50  My story tonight - this was interesting to lea...
#
#           created_at  retweet_count  favorite_count                  source  \
# 0   03-11-2017 17:28              0               1      Twitter for iPhone
# 1   03-11-2017 17:28              0               0          SocialNewsDesk
# 2   03-11-2017 16:37              0               0                  Buffer
# 3   03-11-2017 17:27              0               0                  Google
# 4   03-11-2017 17:27              0               0      Twitter Web Client
# 5   03-11-2017 17:23              0               0      Twitter Web Client
# 6   03-11-2017 17:15              0               0      Twitter Web Client
# 7   03-11-2017 17:15              0               0      Twitter Web Client
# 8   03-11-2017 17:13              0               1      Twitter for iPhone
# 9   03-11-2017 17:11              1               0      Twitter Web Client
# 10  03-11-2017 17:09              0               0             SocialOomph
# 11  03-11-2017 17:06              0               0      Twitter for iPhone
# 12  03-11-2017 17:06              1               2      Crowdfire - Go Big
# 13  03-11-2017 17:00              0               0     Twitter for Android
# 14  03-11-2017 17:00              0               0      Twitter Web Client
# 15  03-11-2017 17:00              0               0               TweetDeck
# 16  03-11-2017 17:00              0               0                 dlvr.it
# 17  03-11-2017 17:00              0               1               TweetDeck
# 18  03-11-2017 16:59              1               0         Mobile Web (M2)
# 19  03-11-2017 16:58              0               0      Twitter for iPhone
# 20  03-11-2017 16:57              0               0      Twitter Web Client
# 21  03-11-2017 16:56              0               0             SocialOomph
# 22  03-11-2017 16:55              0               0                   IFTTT
# 23  03-11-2017 16:55              5               8               Hootsuite
# 24  03-11-2017 16:53              0               0                 dlvr.it
# 25  03-11-2017 16:53              0               3      Twitter for iPhone
# 26  03-11-2017 16:52              0               0             SocialOomph
# 27  03-11-2017 16:50              0               0               Hootsuite
# 28  03-11-2017 16:47              0               0              Statusbrew
# 29  03-11-2017 16:46              0               0                   IFTTT
# 30  03-11-2017 16:46              0               0       New York City Now
# 31  03-11-2017 16:40              0               0          CorrectBaeNews
# 32  03-11-2017 16:40              1               1                 dlvr.it
# 33  03-11-2017 16:39              3               0      Twitter Web Client
# 34  03-11-2017 16:37              0               0                  Buffer
# 35  03-11-2017 16:34              0               1      Twitter Web Client
# 36  03-11-2017 16:34              1               1      Twitter Web Client
# 37  03-11-2017 16:30              1               0               eClincher
# 38  03-11-2017 16:27              0               0                 dlvr.it
# 39  03-11-2017 16:20             12               4                Facebook
# 40  03-11-2017 16:18              0               0            The lnformer
# 41  03-11-2017 16:17              4              13      Twitter for iPhone
# 42  03-11-2017 16:15              0               2             SocialOomph
# 43  04-11-2017 00:17              0               0                   IFTTT
# 44  04-11-2017 00:15              0               0          Tweet Old Post
# 45  04-11-2017 00:13              0               0                   IFTTT
# 46  04-11-2017 00:13              0               0  MyAllies Breaking News
# 47  04-11-2017 00:11              1               0      Twitter Web Client
# 48  04-11-2017 00:10              0               0      Twitter for iPhone
# 49  03-11-2017 23:53              0               1      Twitter Web Client
#
#     length       user_id user_screen_name               user_name  ...  \
# 0       90  8.800000e+17   itsabinakelley              Erica Kane  ...
# 1      132  1.881336e+07             WAOW                    WAOW  ...
# 2      112  2.722783e+08    HOUmanitarian           HOUmanitarian  ...
# 3       89  3.360066e+07          gdubb79         Gabriel Woofter  ...
# 4       97  1.844070e+07     TexasAmerica            TexasAmerica  ...
# 5      138  4.111482e+08   CelloMomOnCars        CelloMom on Cars  ...
# 6       81  2.565304e+09     ChefCrayCafe         TrumpApocalypse  ...
# 7      144  3.086078e+08      cburgessDDH       Christian Burgess  ...
# 8      139  5.366455e+08  PittBusinessRev    Pitt Business Review  ...
# 9      107  7.401404e+07        GaltsGirl            Michelle Ray  ...
# 10      87  2.860606e+07      earthscraft             Earthscraft  ...
# 11     127  9.230000e+17    Texaskookster          Miguel Fernand  ...
# 12     108  2.030564e+08          ogunner                  Gunner  ...
# 13     121  4.767313e+07    confusedabout                       D  ...
# 14     140  7.970000e+17    DerrickChubbs          Derrick Chubbs  ...
# 15     117  3.636938e+07           SAAFdn    San Antonio Area Fdn  ...
# 16      78  8.584223e+07    LakeJacksonTX    City of Lake Jackson  ...
# 17     140  5.658569e+08     BonfireWings            BonfireWings  ...
# 18     100  8.840000e+17     NotFake_News               Real News  ...
# 19      88  3.312831e+09     hailey_bazan            Hailey Bazan  ...
# 20     123  2.539077e+08    OlympicSystem     Olympic Restoration  ...
# 21      87  1.807321e+07         gemstars                 GemStar  ...
# 22     139  6.221975e+08     TylkaLawFirm          Tylka Law Firm  ...
# 23     136  3.891087e+07        kyle_park               Kyle Park  ...
# 24      90  8.420000e+17     WorldConserv      World Conservative  ...
# 25     140  3.280866e+09    HumbleISD_DWE     Deerwood Elementary  ...
# 26      87  1.951139e+07         northmix                Northmix  ...
# 27     139  5.313593e+07          Good360                 Good360  ...
# 28     140  2.828302e+09  Crowdfund_Promo      Crowdfunding Promo  ...
# 29     102  1.355741e+06         zennie62          Zennie Abraham  ...
# 30     139  5.393232e+07        NewYorkCP            New York Now  ...
# 31     128  7.040000e+17  CorrectBae_News         CorrectBae News  ...
# 32     110  5.524684e+07     KingwoodNews       Kingwood Observer  ...
# 33     104  1.619857e+07      annatinsley        Anna M.  Tinsley  ...
# 34     112  2.722783e+08    HOUmanitarian           HOUmanitarian  ...
# 35     136  3.502808e+07       TXSeaGrant         Texas Sea Grant  ...
# 36     140  2.193188e+07   EverettAquaSox         Everett AquaSox  ...
# 37     130  8.640000e+17      NelsonBros1         Nelson Brothers  ...
# 38     110  5.492795e+07   AtascocitaNews     Atascocita Observer  ...
# 39     143  1.305545e+09           nycscr    Second Chance Rescue  ...
# 40     118  1.288325e+08     The_lnformer            The Informer  ...
# 41     140  8.536282e+07             UTSA                    UTSA  ...
# 42     126  4.595865e+08  SocialInChicago        Social N Chicago  ...
# 43     109  3.229678e+09    drone_reviews            DroneReviews  ...
# 44     137  8.970000e+17       AwuavWorld                   Awuav  ...
# 45      84  8.410000e+17  the_best_drones              John Drone  ...
# 46     118  2.397976e+09     MyAlliesNews           MyAllies News  ...
# 47     135  5.002436e+07     nancycbarnes            Nancy Barnes  ...
# 48     139  2.780617e+07       SparkleLeo  Sparkle Major Key ð  ...
# 49     140  4.680210e+08      SarafinaKSN      Sara Berlinger KSN  ...
#
#    user_followers_count user_friends_count                   user_location  \
# 0                   299                410                   made in japan
# 1                 13095                768               Wausau, Wisconsin
# 2                  4261               3956          Houston, Texas, U.S.A.
# 3                   220                683                             NaN
# 4                  1146               5000                           Texas
# 5                   609                861                             USA
# 6                  1853               1877                   Hamtramck, MI
# 7                  1735               1822                             USA
# 8                   108                 56                  Pittsburgh, PA
# 9                 48398               6575  Where the bourbon flows freely
# 10               233974             125844        British Columbia, Canada
# 11                    7                 17                      Texas, USA
# 12                 2278               1977                          Greece
# 13                 1159                575                   Dallas, Texas
# 14                   56                 17                      Austin, TX
# 15                 6690               1211              San Antonio, Texas
# 16                 2389                 17             Lake Jackson, Texas
# 17                  370                 87                     Houston, TX
# 18                 1019                887                  Pittsburgh, PA
# 19                  133                208                     Houston, TX
# 20                 1103               1086                      Keller, TX
# 21               338672              71976        British Columbia, Canada
# 22                  339                 81                 League City, TX
# 23                75459               7683                             NaN
# 24                59932                467             Victoria, Australia
# 25                  603                 75                    Kingwood, TX
# 26               251561             168218                          Canada
# 27                 9777               6373                  Alexandria, VA
# 28               143163              19711                        New York
# 29               168323              54607       Oakland, CA | SD, Vlogger
# 30                 6509                 52                        New York
# 31                  607               1038                             NaN
# 32                 2665                 55                    Kingwood, TX
# 33                 4025               1693               Fort Worth, Texas
# 34                 4261               3956          Houston, Texas, U.S.A.
# 35                 2025               1880          College Station, Texas
# 36                11704               2886             Everett, Washington
# 37                  194                598                   United States
# 38                 1713                 56                  Atascocita, TX
# 39                 9169                 22                           N.Y.C
# 40                 8265                304                  Washington, DC
# 41                55902               1461                 San Antonio, TX
# 42               137090             135621                    Chicago, IL
# 43                 2006                270                       New York
# 44                  257                478                             NaN
# 45                  245                218                 Los Angeles, CA
# 46                  565                  0                             NaN
# 47                 2533                552                         Houston
# 48                 1178                897                   Manhattan, NY
# 49                  611                626                     Wichita, KS
#
#     user_statuses_count user_verified                 user_url  \
# 0                  3585         False                      NaN
# 1                 53691          True   http://t.co/Ooqm8p3JBi
# 2                 48019         False  https://t.co/xZ5kENca0d
# 3                  5649         False  https://t.co/tJVLcw98YK
# 4                 69033         False                      NaN
# 5                 22625         False   http://t.co/y5U1lgAUyi
# 6                 20244         False                      NaN
# 7                  6475         False   http://t.co/vaCYN2725m
# 8                   237         False  https://t.co/1z4kj7dSo0
# 9                673003          True  https://t.co/ouY6ToYOyO
# 10               295110         False  https://t.co/xNKTCga3qY
# 11                  225         False                      NaN
# 12                27898         False  https://t.co/HeB3Mb5ofW
# 13                53295         False                      NaN
# 14                  315         False  https://t.co/pxpYQIijfK
# 15                 8815         False  https://t.co/WrdvG2fZwn
# 16                 4091          True   http://t.co/3Jy2Zq5y1y
# 17                  980         False   http://t.co/btNrOlrN7s
# 18                19480         False                      NaN
# 19                 2460         False                      NaN
# 20                  103         False  https://t.co/dlMvBuwuyh
# 21               283266         False  https://t.co/sYJuscSX1O
# 22                 1204         False   http://t.co/w0jtNjjnMK
# 23                10155          True  https://t.co/xYJhOvRbxi
# 24               111195         False                      NaN
# 25                  624         False   http://t.co/2i0PRCFBMS
# 26               270324         False  https://t.co/1Ut34VZjl6
# 27                 4582          True   http://t.co/WC2bBVTbiG
# 28                15617         False   http://t.co/as4BeseoqU
# 29               699947         False  https://t.co/oXsSXxizE1
# 30               371980         False  https://t.co/cO3WpWNduA
# 31               147094         False  https://t.co/IZldhLJAGE
# 32                13473         False   http://t.co/J2bCtsQ8Iq
# 33                 5456          True   http://t.co/2uj4Jmj0Aq
# 34                48019         False  https://t.co/xZ5kENca0d
# 35                 4150         False   http://t.co/HpfZyh8FKF
# 36                12513          True   http://t.co/hFzwbydKtz
# 37                  171         False  https://t.co/zZH1a2bsLA
# 38                11462         False   http://t.co/3evGfnt9kR
# 39                28325         False  https://t.co/ZGycxVjHcS
# 40                35508         False  https://t.co/OJw28xTel2
# 41                11835          True  https://t.co/VHxfjgW6aU
# 42               188455         False   http://t.co/Fu85yP4JHO
# 43                35512         False   http://t.co/R1fzhm6cJi
# 44                11536         False                      NaN
# 45                12356         False  https://t.co/TkU2VUgWyd
# 46               558908         False  https://t.co/EMO1mExUVH
# 47                 4308          True   http://t.co/LBDLk3KwVk
# 48                14813         False                      NaN
# 49                 2784         False  https://t.co/mA68qv3kS8
#
#     statuses/followers_count friends/followers_count  user_has_url?  \
# 0                      11.99                    1.37             No
# 1                       4.10                    0.06            Yes
# 2                      11.27                    0.93            Yes
# 3                      25.68                    3.10            Yes
# 4                      60.24                    4.36             No
# 5                      37.15                    1.41            Yes
# 6                      10.92                    1.01             No
# 7                       3.73                    1.05            Yes
# 8                       2.19                    0.52            Yes
# 9                      13.91                    0.14            Yes
# 10                      1.26                    0.54            Yes
# 11                     32.14                    2.43             No
# 12                     12.25                    0.87            Yes
# 13                     45.98                    0.50             No
# 14                      5.63                    0.30            Yes
# 15                      1.32                    0.18            Yes
# 16                      1.71                    0.01            Yes
# 17                      2.65                    0.24            Yes
# 18                     19.12                    0.87             No
# 19                     18.50                    1.56             No
# 20                      0.09                    0.98            Yes
# 21                      0.84                    0.21            Yes
# 22                      3.55                    0.24            Yes
# 23                      0.13                    0.10            Yes
# 24                      1.86                    0.01             No
# 25                      1.03                    0.12            Yes
# 26                      1.07                    0.67            Yes
# 27                      0.47                    0.65            Yes
# 28                      0.11                    0.14            Yes
# 29                      4.16                    0.32            Yes
# 30                     57.15                    0.01            Yes
# 31                    242.33                    1.71            Yes
# 32                      5.06                    0.02            Yes
# 33                      1.36                    0.42            Yes
# 34                     11.27                    0.93            Yes
# 35                      2.05                    0.93            Yes
# 36                      1.07                    0.25            Yes
# 37                      0.88                    3.08            Yes
# 38                      6.69                    0.03            Yes
# 39                      3.09                    0.00            Yes
# 40                      4.30                    0.04            Yes
# 41                      0.21                    0.03            Yes
# 42                      1.37                    0.99            Yes
# 43                     17.70                    0.13            Yes
# 44                     44.89                    1.86             No
# 45                     50.43                    0.89            Yes
# 46                    989.22                    0.00            Yes
# 47                      1.70                    0.22            Yes
# 48                     12.57                    0.76             No
# 49                      4.56                    1.02            Yes
#
#     Final Label
# 0          REAL
# 1          REAL
# 2          REAL
# 3          REAL
# 4          REAL
# 5          REAL
# 6          REAL
# 7          REAL
# 8          REAL
# 9          REAL
# 10         REAL
# 11         FAKE
# 12         REAL
# 13         FAKE
# 14         REAL
# 15         REAL
# 16         REAL
# 17         FAKE
# 18         FAKE
# 19         REAL
# 20         REAL
# 21         REAL
# 22         REAL
# 23         REAL
# 24         REAL
# 25         FAKE
# 26         REAL
# 27         REAL
# 28         FAKE
# 29         REAL
# 30         FAKE
# 31         REAL
# 32         FAKE
# 33         REAL
# 34         REAL
# 35         FAKE
# 36         FAKE
# 37         REAL
# 38         FAKE
# 39         FAKE
# 40         FAKE
# 41         REAL
# 42         REAL
# 43         REAL
# 44         REAL
# 45         REAL
# 46         REAL
# 47         REAL
# 48         REAL
# 49         REAL
#
# [50 rows x 22 columns]

# %%
import plotly.plotly as py
from plotly import graph_objs
plotly.tools.set_credentials_file(username='swmathias', api_key='IUApAvbxLdKWUicRaovv')

# %%
fake = len(tweetsData[tweetsData["Final Label"] == "FAKE"])
real = len(tweetsData[tweetsData["Final Label"] == "REAL"])
dist = [
    graph_objs.Bar(
        x=["fake","real"],
        y=[fake, real],
)]
py.iplot({"data":dist, "layout":graph_objs.Layout(title="Fake and Real Tweets distribution in training set")})
# Out:
# /home/hamdi/anaconda3/lib/python3.7/site-packages/IPython/core/display.py:694: UserWarning:
#
# Consider using IPython.display.IFrame instead
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~swmathias/52.embed" height="525px" width="100%"></iframe>

# %%
import re
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)

def preproces(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
tweetsData['tokenized_text']= tweetsData['text'].apply(preproces)

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/hamdi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Removes stopwords
stop_words = set(stopwords.words('english'))
tweetsData['token_texts'] = tweetsData['tokenized_text'].apply(lambda x : [w for w in x if w.lower() not in stop_words])

# %%
tweetsData.head(5)
# Out:
#    Unique ID                                               text  \
# 0          1  Hurricane Katrina - Saints go to the Superbowl...
# 1          2  Students from Riverview Elementary set a goal ...
# 2          3  Harvey caused more than $74M in damage to floo...
# 3          4  I added a video to a @YouTube playlist https:/...
# 4          5  DFW businesses accused of price gouging during...
#
#          created_at  retweet_count  favorite_count              source  \
# 0  03-11-2017 17:28              0               1  Twitter for iPhone
# 1  03-11-2017 17:28              0               0      SocialNewsDesk
# 2  03-11-2017 16:37              0               0              Buffer
# 3  03-11-2017 17:27              0               0              Google
# 4  03-11-2017 17:27              0               0  Twitter Web Client
#
#    length       user_id user_screen_name        user_name  ...  \
# 0      90  8.800000e+17   itsabinakelley       Erica Kane  ...
# 1     132  1.881336e+07             WAOW             WAOW  ...
# 2     112  2.722783e+08    HOUmanitarian    HOUmanitarian  ...
# 3      89  3.360066e+07          gdubb79  Gabriel Woofter  ...
# 4      97  1.844070e+07     TexasAmerica     TexasAmerica  ...
#
#             user_location user_statuses_count  user_verified  \
# 0           made in japan                3585          False
# 1       Wausau, Wisconsin               53691           True
# 2  Houston, Texas, U.S.A.               48019          False
# 3                     NaN                5649          False
# 4                   Texas               69033          False
#
#                   user_url statuses/followers_count  friends/followers_count  \
# 0                      NaN                    11.99                     1.37
# 1   http://t.co/Ooqm8p3JBi                     4.10                     0.06
# 2  https://t.co/xZ5kENca0d                    11.27                     0.93
# 3  https://t.co/tJVLcw98YK                    25.68                     3.10
# 4                      NaN                    60.24                     4.36
#
#    user_has_url? Final Label  \
# 0             No        REAL
# 1            Yes        REAL
# 2            Yes        REAL
# 3            Yes        REAL
# 4             No        REAL
#
#                                       tokenized_text  \
# 0  [Hurricane, Katrina, -, Saints, go, to, the, S...
# 1  [Students, from, Riverview, Elementary, set, a...
# 2  [Harvey, caused, more, than, $, 74, M, in, dam...
# 3  [I, added, a, video, to, a, @YouTube, playlist...
# 4  [DFW, businesses, accused, of, price, gouging,...
#
#                                          token_texts
# 0  [Hurricane, Katrina, -, Saints, go, Superbowl,...
# 1  [Students, Riverview, Elementary, set, goal, $...
# 2  [Harvey, caused, $, 74, damage, flood, control...
# 3  [added, video, @YouTube, playlist, https://t.c...
# 4  [DFW, businesses, accused, price, gouging, Hur...
#
# [5 rows x 24 columns]

# %%
 #function defined to calculate number of occurences of a symbol
def count_occurences(character, word_array):
    counter = 0
    for j, word in enumerate(word_array):
        for char in word:
            if char == character:
                counter += 1
    return counter

# %%
#calculates number of ?, !, hashtags and mentions
tweetsData['no_of_question_marks'] = tweetsData['token_texts'].apply(lambda txt: count_occurences("?", txt)) 
tweetsData['no_of_exclamation_marks'] = tweetsData['token_texts'].apply(lambda txt: count_occurences("!", txt)) 
tweetsData['no_of_hashtags'] = tweetsData['token_texts'].apply(lambda txt: count_occurences("#", txt)) 
tweetsData['no_of_mentions'] = tweetsData['token_texts'].apply(lambda txt: count_occurences("@", txt))

# %%
def count_by_regex(regex,plain_text):
    return len(re.findall(regex,plain_text))

# %%
tweetsData.head(5)
# Out:
#    Unique ID                                               text  \
# 0          1  Hurricane Katrina - Saints go to the Superbowl...
# 1          2  Students from Riverview Elementary set a goal ...
# 2          3  Harvey caused more than $74M in damage to floo...
# 3          4  I added a video to a @YouTube playlist https:/...
# 4          5  DFW businesses accused of price gouging during...
#
#          created_at  retweet_count  favorite_count              source  \
# 0  03-11-2017 17:28              0               1  Twitter for iPhone
# 1  03-11-2017 17:28              0               0      SocialNewsDesk
# 2  03-11-2017 16:37              0               0              Buffer
# 3  03-11-2017 17:27              0               0              Google
# 4  03-11-2017 17:27              0               0  Twitter Web Client
#
#    length       user_id user_screen_name        user_name  ...  \
# 0      90  8.800000e+17   itsabinakelley       Erica Kane  ...
# 1     132  1.881336e+07             WAOW             WAOW  ...
# 2     112  2.722783e+08    HOUmanitarian    HOUmanitarian  ...
# 3      89  3.360066e+07          gdubb79  Gabriel Woofter  ...
# 4      97  1.844070e+07     TexasAmerica     TexasAmerica  ...
#
#   statuses/followers_count friends/followers_count  user_has_url?  \
# 0                    11.99                    1.37             No
# 1                     4.10                    0.06            Yes
# 2                    11.27                    0.93            Yes
# 3                    25.68                    3.10            Yes
# 4                    60.24                    4.36             No
#
#    Final Label                                     tokenized_text  \
# 0         REAL  [Hurricane, Katrina, -, Saints, go, to, the, S...
# 1         REAL  [Students, from, Riverview, Elementary, set, a...
# 2         REAL  [Harvey, caused, more, than, $, 74, M, in, dam...
# 3         REAL  [I, added, a, video, to, a, @YouTube, playlist...
# 4         REAL  [DFW, businesses, accused, of, price, gouging,...
#
#                                          token_texts  no_of_question_marks  \
# 0  [Hurricane, Katrina, -, Saints, go, Superbowl,...                     0
# 1  [Students, Riverview, Elementary, set, goal, $...                     0
# 2  [Harvey, caused, $, 74, damage, flood, control...                     0
# 3  [added, video, @YouTube, playlist, https://t.c...                     0
# 4  [DFW, businesses, accused, price, gouging, Hur...                     0
#
#   no_of_exclamation_marks  no_of_hashtags  no_of_mentions
# 0                       0               0               0
# 1                       0               0               0
# 2                       0               0               1
# 3                       0               0               1
# 4                       0               0               0
#
# [5 rows x 28 columns]

# %%
#Calculates number of URLs in a tweet
tweetsData['no_of_urls'] = tweetsData['text'].apply(lambda txt:count_by_regex("http.?://[^\s]+[\s]?",txt))

# %%
#Not working as of now. Need to look at it later if needed
class EmoticonDetector:
    emoticons = {}

    def __init__(self, emoticon_file="emoticons.txt"):
        from pathlib import Path
        content = Path(emoticon_file).read_text()
        positive = True
        for line in content.split("\n"):
            if "positive" in line.lower():
                positive = True
                continue
            elif "negative" in line.lower():
                positive = False
                continue

            self.emoticons[line] = positive

    def is_positive(self, emoticon):
        if emoticon in self.emoticons:
            return self.emoticons[emoticon]
        return False

    def is_emoticon(self, to_check):
        return to_check in self.emoticons

# %%
def count_by_lambda(expression, word_array):
    return len(list(filter(expression, word_array)))

# %%
#May need this code later. But this code does not work
ed = EmoticonDetector()
tweetsData['no_of_positive_emoticons'] = tweetsData['text'].apply(lambda txt: count_by_lambda(lambda word: ed.is_emoticon(word) and ed.is_positive(word), txt))

# %%
#tweetsData.to_csv("FinalDS_AdditionalFeatures.csv")

# %%
tweetsData['no_of_uppercase_words'] = tweetsData['tokenized_text'].apply(lambda txt: count_by_lambda(lambda word: word == word.upper(),txt))

# %%
# Function to Remove URLs and mentions from tweets
def remove_url_by_regex(pattern,string):
    return re.sub(pattern,"", string)

# %%
#Removes URLs
tweetsData['cleaned_text'] = tweetsData['text'].apply(lambda txt:remove_url_by_regex("http.?://[^\s]+[\s]?",txt))

# %%
#Removes mentions
tweetsData['cleaned_text'] = tweetsData['cleaned_text'].apply(lambda txt:remove_url_by_regex(r'(?:@[\w_]+)',txt))

# %%
#strs = "how much for the maple syrup??? $20.99? That's?ricidulous!!!"
# print(strs)
# nstr = re.sub(r'[?|$|.|!]',r'',strs)
# print (nstr)

# %%
#Calculates number of colon marks
tweetsData['no_of_colon_marks'] = tweetsData['cleaned_text'].apply(lambda txt: count_occurences(":", txt))

# %%
#Remove punctuation marks
tweetsData['cleaned_text'] = tweetsData['cleaned_text'].apply(lambda txt:remove_url_by_regex(r'[,|:|\|=|&|;|%|$|@|^|*|-|#|?|!|.]',txt))

# %%
#Counts number of words
tweetsData['no_of_words'] = tweetsData['cleaned_text'].apply(lambda txt:len(re.findall(r'\w+',txt)))

# %%
tweetsData.head(2)
# Out:
#    Unique ID                                               text  \
# 0          1  Hurricane Katrina - Saints go to the Superbowl...
# 1          2  Students from Riverview Elementary set a goal ...
#
#          created_at  retweet_count  favorite_count              source  \
# 0  03-11-2017 17:28              0               1  Twitter for iPhone
# 1  03-11-2017 17:28              0               0      SocialNewsDesk
#
#    length       user_id user_screen_name   user_name  ...  \
# 0      90  8.800000e+17   itsabinakelley  Erica Kane  ...
# 1     132  1.881336e+07             WAOW        WAOW  ...
#
#   no_of_question_marks no_of_exclamation_marks  no_of_hashtags  \
# 0                    0                       0               0
# 1                    0                       0               0
#
#    no_of_mentions no_of_urls  no_of_positive_emoticons  no_of_uppercase_words  \
# 0               0          0                         0                      2
# 1               0          1                         0                      5
#
#                                         cleaned_text  no_of_colon_marks  \
# 0  Hurricane Katrina - Saints go to the Superbowl...                  0
# 1  Students from Riverview Elementary set a goal ...                  0
#
#    no_of_words
# 0           12
# 1           17
#
# [2 rows x 34 columns]

# %%
tweetsData.to_csv("FinalDS_AdditionalFeatures.csv")

# %%
tweetsData.dtypes
# Out:
# Unique ID                     int64
# text                         object
# created_at                   object
# retweet_count                 int64
# favorite_count                int64
# source                       object
# length                        int64
# user_id                     float64
# user_screen_name             object
# user_name                    object
# user_created_at              object
# user_description             object
# user_followers_count          int64
# user_friends_count            int64
# user_location                object
# user_statuses_count           int64
# user_verified                  bool
# user_url                     object
# statuses/followers_count    float64
# friends/followers_count     float64
# user_has_url?                object
# Final Label                  object
# tokenized_text               object
# token_texts                  object
# no_of_question_marks          int64
# no_of_exclamation_marks       int64
# no_of_hashtags                int64
# no_of_mentions                int64
# no_of_urls                    int64
# no_of_positive_emoticons      int64
# no_of_uppercase_words         int64
# cleaned_text                 object
# no_of_colon_marks             int64
# no_of_words                   int64
# dtype: object

# %%
tweetsData.drop(["statuses/followers_count","friends/followers_count"],axis=1,inplace=True)

# %%
tweetsData["user_has_url?"]=hamdi

# %%
tweetsData['user_has_url?'] = tweetsData['user_has_url?'].map( {'Yes':1, 'No':0} )

# %%
tweetsData['Final Label'] = tweetsData['Final Label'].map( {'FAKE':1, 'REAL':0} )
tweetsData['user_verified'] = tweetsData['user_verified'].map( {'Yes':1, 'No':0} )

# %%
tweetsData.shape
# Out:
# (250, 30)

# %%
tweetsData.drop(["Unique ID"],axis=1,inplace=True)

# %%
tweetsData.to_csv("FinalDS_AdditionalFeatures.csv")
